# %%
# importing the necessary libraries
import pandas as pd
import plotly.express as px

# reading the data file
car_data = pd.read_csv('../vehicles.csv') 

# creating a histogram to visualize the distribution of odometer
fig = px.histogram(car_data, x="odometer")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 10
#       6 car_data = pd.read_csv('../vehicles.csv')
#       7
#       8 # creating a histogram to visualize the distribution of odometer
#       9 fig = px.histogram(car_data, x="odometer")
# ---> 10 fig.show()
#
# File ~\anaconda3\envs\vehicles_env\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~\anaconda3\envs\vehicles_env\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# importing the necessary libraries
import pandas as pd
import plotly.express as px

# reading the data file
car_data = pd.read_csv('../vehicles.csv')

# creating a scatter plot to visualize the relationship between odometer and price
fig = px.scatter(car_data, x="odometer", y="price") 
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       6 car_data = pd.read_csv('vehicles.csv')
#       7
#       8 # creating a scatter plot to visualize the relationship between odometer and price
#       9 fig = px.scatter(car_data, x="odometer", y="price")
# ---> 10 fig.show()
#
# File ~\anaconda3\envs\vehicles_env\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File ~\anaconda3\envs\vehicles_env\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
